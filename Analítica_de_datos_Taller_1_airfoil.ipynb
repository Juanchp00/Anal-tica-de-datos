# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanchp00/Anal-tica-de-datos/blob/main/Anal%C3%ADtica_de_datos_Taller_1_airfoil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Taller 1
# **Segunda Base de datos**
#
# **Analítica de datos**
#
# **Juan José Chamorro Paz**

# %% [markdown]
# #Base de datos **airfoil_self_noise**

# %%
#cargar datos desde drive acceso libre
FILEID = "1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O airfoil_self_noise.dat && rm -rf /tmp/cookies.txt
# Out:
# --2021-04-14 17:13:25--  https://docs.google.com/uc?export=download&confirm=&id=1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A
# Resolving docs.google.com (docs.google.com)... 172.217.3.14, 2607:f8b0:4026:803::200e
# Connecting to docs.google.com (docs.google.com)|172.217.3.14|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-5k-docs.googleusercontent.com/docs/securesc/qt8ofgl89b4traokiv8d24s3fad4ktj6/jg1rnvl4qgn8nal57khjhel83hpthal4/1618420350000/02220634972831643091/07920483908762406620Z/1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A?e=download [following]
# --2021-04-14 17:13:25--  https://doc-0c-5k-docs.googleusercontent.com/docs/securesc/qt8ofgl89b4traokiv8d24s3fad4ktj6/jg1rnvl4qgn8nal57khjhel83hpthal4/1618420350000/02220634972831643091/07920483908762406620Z/1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A?e=download
# Resolving doc-0c-5k-docs.googleusercontent.com (doc-0c-5k-docs.googleusercontent.com)... 172.217.3.1, 2607:f8b0:4026:800::2001
# Connecting to doc-0c-5k-docs.googleusercontent.com (doc-0c-5k-docs.googleusercontent.com)|172.217.3.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=hh0ntd5cd16go&continue=https://doc-0c-5k-docs.googleusercontent.com/docs/securesc/qt8ofgl89b4traokiv8d24s3fad4ktj6/jg1rnvl4qgn8nal57khjhel83hpthal4/1618420350000/02220634972831643091/07920483908762406620Z/1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A?e%3Ddownload&hash=kejn4obh5amn0n1cfcodg8m7f0eufh91 [following]
# --2021-04-14 17:13:26--  https://docs.google.com/nonceSigner?nonce=hh0ntd5cd16go&continue=https://doc-0c-5k-docs.googleusercontent.com/docs/securesc/qt8ofgl89b4traokiv8d24s3fad4ktj6/jg1rnvl4qgn8nal57khjhel83hpthal4/1618420350000/02220634972831643091/07920483908762406620Z/1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A?e%3Ddownload&hash=kejn4obh5amn0n1cfcodg8m7f0eufh91
# Connecting to docs.google.com (docs.google.com)|172.217.3.14|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0c-5k-docs.googleusercontent.com/docs/securesc/qt8ofgl89b4traokiv8d24s3fad4ktj6/jg1rnvl4qgn8nal57khjhel83hpthal4/1618420350000/02220634972831643091/07920483908762406620Z/1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A?e=download&nonce=hh0ntd5cd16go&user=07920483908762406620Z&hash=8dagbihm5mt9p07hru5tos4ko9cch5rr [following]
# --2021-04-14 17:13:26--  https://doc-0c-5k-docs.googleusercontent.com/docs/securesc/qt8ofgl89b4traokiv8d24s3fad4ktj6/jg1rnvl4qgn8nal57khjhel83hpthal4/1618420350000/02220634972831643091/07920483908762406620Z/1BaHtJ8wcU6BiKsm9f3PIuLxj_TuIE--A?e=download&nonce=hh0ntd5cd16go&user=07920483908762406620Z&hash=8dagbihm5mt9p07hru5tos4ko9cch5rr
# Connecting to doc-0c-5k-docs.googleusercontent.com (doc-0c-5k-docs.googleusercontent.com)|172.217.3.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59984 (59K) [application/octet-stream]
# Saving to: ‘airfoil_self_noise.dat’
#
# airfoil_self_noise. 100%[===================>]  58.58K  --.-KB/s    in 0.03s
#
# 2021-04-14 17:13:26 (1.68 MB/s) - ‘airfoil_self_noise.dat’ saved [59984/59984]

# %%
#Paso 1: Lectura
import pandas as pd #https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
dat_path = 'airfoil_self_noise.dat' #https://archive.ics.uci.edu/ml/datasets/Airfoil+Self-Noise#

Xdata = pd.read_csv(dat_path,header = None, delim_whitespace=True, error_bad_lines=False )
#Corroborar si el orden de los nombres si es el correcto.
Xdata.rename(columns = {0:'Frequency', 1:'Angle_of_attack', 2:'Chord_length', 3:'Free-stream_velocity', 4:'Suction_side_displacement_thickness', 5:'Scaled_sound_pressure_level'}, inplace = True)
Xdata.head()
# Out:
#    Frequency  ...  Scaled_sound_pressure_level
# 0        800  ...                      126.201
# 1       1000  ...                      125.201
# 2       1250  ...                      125.951
# 3       1600  ...                      127.591
# 4       2000  ...                      127.461
#
# [5 rows x 6 columns]

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# magic function to render figure
# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)


#crear carpeta con resultados
import os
try:
  os.mkdir('results')
except:
  print("Carpeta results ya existe")
Xdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Frequency                            1503 non-null   int64
#  1   Angle_of_attack                      1503 non-null   float64
#  2   Chord_length                         1503 non-null   float64
#  3   Free-stream_velocity                 1503 non-null   float64
#  4   Suction_side_displacement_thickness  1503 non-null   float64
#  5   Scaled_sound_pressure_level          1503 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 70.6 KB

# %%
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
Xtrain, Xtest = train_test_split(Xdata,test_size=0.3)
col_sal = "Free-stream_velocity"
ytrain = Xtrain[col_sal]
ytest = Xtest[col_sal]
Xtrain.drop(columns=col_sal,inplace=True)
Xtest.drop(columns=col_sal,inplace=True)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="most_frequent")
ytrain = imputer.fit_transform(pd.DataFrame(ytrain))
ytrain = ytrain.reshape(-1)

ytest = imputer.transform(pd.DataFrame(ytest))
ytest = ytest.reshape(-1)

print(ytrain.shape, ytest.shape)
# Out:
# (1052,) (451,)

# %%
ytest[:5]
# Out:
# array([39.6, 71.3, 31.7, 39.6, 39.6])

# %%
ytrain[:5]
# Out:
# array([31.7, 71.3, 71.3, 39.6, 31.7])

# %%
import matplotlib.pyplot as plt
plt.hist(ytrain,bins = 100)
plt.show()

plt.boxplot(ytrain)
plt.show()

# %%
Xdata['Free-stream_velocity'].value_counts()
# Out:
# 39.6    480
# 71.3    465
# 31.7    281
# 55.5    277
# Name: Free-stream_velocity, dtype: int64

# %% [markdown]
# ##Matriz de correlación e histograma##

# %%
corr_matrix = Xdata.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col0,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col1,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col2,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col3,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row4_col4,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col1{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col2{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col3{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col4{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col5,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col2,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col1,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row4_col3,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row5_col0,#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row5_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col0{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col3{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col4{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col5{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col0{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col3{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col4{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col5{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col0{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col1{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col2{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col4{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col5{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row4_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row4_col1{
#             background-color:  #e67259;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row4_col2{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row4_col5{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row5_col1{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row5_col2{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row5_col3{
#             background-color:  #6282ea;
#             color:  #000000;
#         }</style><table id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Frequency</th>        <th class="col_heading level0 col1" >Angle_of_attack</th>        <th class="col_heading level0 col2" >Chord_length</th>        <th class="col_heading level0 col3" >Free-stream_velocity</th>        <th class="col_heading level0 col4" >Suction_side_displacement_thickness</th>        <th class="col_heading level0 col5" >Scaled_sound_pressure_level</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002level0_row0" class="row_heading level0 row0" >Frequency</th>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col1" class="data row0 col1" >-0.272765</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col2" class="data row0 col2" >-0.003661</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col3" class="data row0 col3" >0.133664</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col4" class="data row0 col4" >-0.230107</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row0_col5" class="data row0 col5" >-0.390711</td>
#             </tr>
#             <tr>
#                         <th id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002level0_row1" class="row_heading level0 row1" >Angle_of_attack</th>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col0" class="data row1 col0" >-0.272765</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col2" class="data row1 col2" >-0.504868</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col3" class="data row1 col3" >0.058760</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col4" class="data row1 col4" >0.753394</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row1_col5" class="data row1 col5" >-0.156108</td>
#             </tr>
#             <tr>
#                         <th id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002level0_row2" class="row_heading level0 row2" >Chord_length</th>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col0" class="data row2 col0" >-0.003661</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col1" class="data row2 col1" >-0.504868</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col3" class="data row2 col3" >0.003787</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col4" class="data row2 col4" >-0.220842</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row2_col5" class="data row2 col5" >-0.236162</td>
#             </tr>
#             <tr>
#                         <th id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002level0_row3" class="row_heading level0 row3" >Free-stream_velocity</th>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col0" class="data row3 col0" >0.133664</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col1" class="data row3 col1" >0.058760</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col2" class="data row3 col2" >0.003787</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col4" class="data row3 col4" >-0.003974</td>
#                         <td id="T_13824ec4_9d4a_11eb_b20d_0242ac1c0002row3_col5" class="data row3 col5" >0.125103</td>
#             </tr>
#             <tr>
#                         <t

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
Xdata.hist(bins=50, figsize=(20,15))
plt.tight_layout()
plt.savefig('results/attribute_histogram_plots.pdf', format='pdf', dpi=300)
plt.show()

# %% [markdown]
# ##Código de Regresión lineal##

# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import mean_absolute_error as msa

# %%
X_train, X_test, y_train, y_test = train_test_split(Xtrain, ytrain, test_size=0.30)
print(X_train.shape); print(X_test.shape)
# Out:
# (736, 5)
# (316, 5)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_train_lr= lr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lr)))
print(r2_score(y_train, pred_train_lr))

pred_test_lr= lr.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lr))) 
print(r2_score(y_test, pred_test_lr))
# Out:
# 14.570962752084451
# 0.1320403369464307
# 15.06301764455304
# 0.08194863470422309

# %%
#Gráficas de regresión con datos nuevos
plt.scatter(y_test, pred_test_lr, color ='b')
plt.plot(y_test, y_test, color ='k')
plt.xlabel('Medición')
plt.ylabel('Predicción')
plt.title('Free-stream_velocity')
plt.grid() 
plt.show()

fig, ax = plt.subplots()
ax.scatter(y_test, pred_test_lr, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Medición')
ax.set_ylabel('Predicción')
ax.set_title('Free-stream_velocity')
plt.grid()
plt.show()

# %%
print('MAE_test=', msa(y_test,pred_test_lr))
# Out:
# MAE_test= 13.538717647881283

# %% [markdown]
# ##Código de Regresión lineal Ridge##

# %%
rr = Ridge(alpha=0.01)
rr.fit(X_train, y_train) 
pred_train_rr= rr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train, pred_train_rr)))
print(r2_score(y_train, pred_train_rr))

pred_test_rr= rr.predict(X_test)
print(np.sqrt(mean_squared_error(y_test, pred_test_rr))) 
print(r2_score(y_test, pred_test_rr))
# Out:
# 14.571388091485522
# 0.1319896631731422
# 15.05436233111444
# 0.08300336883350723

# %%
#Gráficas de regresión con datos nuevos
plt.scatter(y_test, pred_test_lr, color ='b')
plt.plot(pred_test_lr, pred_test_lr, color ='k')
plt.xlabel('Medición')
plt.ylabel('Predicción')
plt.title('Free-stream_velocity')
plt.grid() 
plt.show()

fig, ax = plt.subplots()
ax.scatter(y_test, pred_test_lr, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Medición')
ax.set_ylabel('Predicción')
ax.set_title('Free-stream_velocity')
plt.grid()
plt.show()

# %%
print('MAE_test=', msa(y_test,pred_test_rr))
# Out:
# MAE_test= 13.533863621600423

# %% [markdown]
# ##Código de Regresión lineal Lasso##

# %%
model_lasso = Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)
print(np.sqrt(mean_squared_error(y_train, pred_train_lasso)))
print(r2_score(y_train, pred_train_lasso))

pred_test_lasso= model_lasso.predict(X_test)
print(np.sqrt(mean_squared_error(y_test, pred_test_lasso))) 
print(r2_score(y_test, pred_test_lasso))
# Out:
# 14.584095598055256
# 0.13047504333710458
# 15.024660494818692
# 0.08661821678433579

# %%
#Gráficas de regresión con datos nuevos
plt.scatter(y_test, pred_test_lr, color ='b')
plt.plot(y_test, y_test, color ='k')
plt.xlabel('Medición')
plt.ylabel('Predicción')
plt.title('Free-stream_velocity')
plt.grid() 
plt.show()

fig, ax = plt.subplots()
ax.scatter(y_test, pred_test_lr, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Medición')
ax.set_ylabel('Predicción')
ax.set_title('Free-stream_velocity')
plt.grid()
plt.show()

# %%
print('MAE_test=', msa(y_test,pred_test_lasso))
# Out:
# MAE_test= 13.529758758030288

# %% [markdown]
# ##Código de Regresión lineal ElasticNet##

# %%
model_enet = ElasticNet(alpha = 0.01)
model_enet.fit(X_train, y_train) 
pred_train_enet= model_enet.predict(X_train)
print(np.sqrt(mean_squared_error(y_train, pred_train_enet)))
print(r2_score(y_train, pred_train_enet))

pred_test_enet= model_enet.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_enet)))
print(r2_score(y_test, pred_test_enet))
# Out:
# 14.701538626957529
# 0.11641440868916009
# 15.07042327314386
# 0.0810457055730548

# %%
#Gráficas de regresión con datos nuevos
plt.scatter(y_test, pred_test_lr, color ='b')
plt.plot(y_test, y_test, color ='k')
plt.xlabel('Medición')
plt.ylabel('Predicción')
plt.title('Free-stream_velocity')
plt.grid() 
plt.show()

fig, ax = plt.subplots()
ax.scatter(y_test, pred_test_lr, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Medición')
ax.set_ylabel('Predicción')
ax.set_title('Free-stream_velocity')
plt.grid()
plt.show()

# %%
print('MAE_test=', msa(y_test,pred_test_enet))
# Out:
# MAE_test= 13.6015997788231

# %% [markdown]
# ##Código de Regresión KernelRidge##

# %%
krr = KernelRidge(alpha=1.0,kernel='polynomial',degree=3, coef0=1, kernel_params=None)
krr.fit(X_train,y_train)
pred_train_krr=krr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train, pred_train_krr)))
print(r2_score(y_train, pred_train_krr))

pred_test_krr=krr.predict(X_test)
print(np.sqrt(mean_squared_error(y_test, pred_test_krr)))
print(r2_score(y_test, pred_test_krr))
# Out:
# 14.17242909765742
# 0.17887054245416567
# 14.65480304579071
# 0.13103360146378062

# %%
#Gráficas de regresión con datos nuevos
plt.scatter(y_test, pred_test_lr, color ='b')
plt.plot(y_test, y_test, color ='k')
plt.xlabel('Medición')
plt.ylabel('Predicción')
plt.title('Free-stream_velocity')
plt.grid() 
plt.show()

fig, ax = plt.subplots()
ax.scatter(y_test, pred_test_lr, edgecolors=(0, 0, 0))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Medición')
ax.set_ylabel('Predicción')
ax.set_title('Free-stream_velocity')
plt.grid()
plt.show()

# %%
print('MAE_test=', msa(y_test,pred_test_krr))
# Out:
# MAE_test= 12.840016226828853
